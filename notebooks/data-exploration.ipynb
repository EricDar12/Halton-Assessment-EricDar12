# %%
import polars as pl
from utils import getConnection
from utils import cleanContracts
con, dataset_path = getConnection()
pl.Config.set_tbl_rows(100)
# Out:
# polars.config.Config

# %%
con.execute("""
    CREATE TEMP TABLE contracts AS
    SELECT *
    FROM read_csv_auto(
        '{0}',
        delim = ',',
        header = true,
        strict_mode = false,
        all_varchar = true
    )
""".format(dataset_path))
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
con.sql("""
SELECT * FROM contracts
        WHERE reference_number LIKE 'C-2019-2020-Q4-2'
""")
# Out:
# ┌──────────────────┬────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────┬────────────┬───────────────┬──────────────────────┬──────────────────────────────────────────────────────────────────┬───────────────────────────────────────────────────────┬───────────────────────┬───────────────┬────────────────┬────────────────┬─────────────────┬───────────────────────────────────┬─────────────────────────────────────────────┬─────────────────────────────┬─────────────────────────────────────┬─────────────────────┬─────────────────┬─────────────┬────────────────┬────────────────┬───────────────────┬────────────────────────┬──────────────────────────┬────────────────────────────┬─────────────────────┬────────────────────────────────────┬───────────────────────┬───────────────────────────────────┬───────────────────────┬────────────────────┬───────────────────────┬─────────────────┬──────────────────┬────────────────┬──────────────────────┬────────────────┬─────────────────────────┬──────────────────┬─────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ reference_number │ procurement_id │                                                           vendor_name                                                            │ vendor_postal_code │ buyer_name │ contract_date │ economic_object_code │                          description_en                          │                    description_fr                     │ contract_period_start │ delivery_date │ contract_value │ original_value │ amendment_value │            comments_en            │                 comments_fr                 │   additional_comments_en    │       additional_comments_fr        │ agreement_type_code │ trade_agreement │ land_claims │ commodity_type │ commodity_code │ country_of_vendor │ solicitation_procedure │ limited_tendering_reason │ trade_agreement_exceptions │ indigenous_business │ indigenous_business_excluding_psib │ intellectual_property │ potential_commercial_exploitation │ former_public_servant │ contracting_entity │ standing_offer_number │ instrument_type │ ministers_office │ number_of_bids │ article_6_exceptions │ award_criteria │ socioeconomic_indicator │ reporting_period │  owner_org  │                                            owner_org_title                                             │
# │     varchar      │    varchar     │                                                             varchar                                                              │      varchar       │  varchar   │    varchar    │       varchar        │                             varchar                              │                        varchar                        │        varchar        │    varchar    │    varchar     │    varchar     │     varchar     │              varchar              │                   varchar                   │           varchar           │               varchar               │       varchar       │     varchar     │   varchar   │    varchar     │    varchar     │      varchar      │        varchar         │         varchar          │          varchar           │       varchar       │              varchar               │        varchar        │              varchar              │        varchar        │      varchar       │        varchar        │     varchar     │     varchar      │    varchar     │       varchar        │    varchar     │         varchar         │     varchar      │   varchar   │                                                varchar                                                 │
# ├──────────────────┼────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────┼────────────┼───────────────┼──────────────────────┼──────────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────┼───────────────────────┼───────────────┼────────────────┼────────────────┼─────────────────┼───────────────────────────────────┼─────────────────────────────────────────────┼─────────────────────────────┼─────────────────────────────────────┼─────────────────────┼─────────────────┼─────────────┼────────────────┼────────────────┼───────────────────┼────────────────────────┼──────────────────────────┼────────────────────────────┼─────────────────────┼────────────────────────────────────┼───────────────────────┼───────────────────────────────────┼───────────────────────┼────────────────────┼───────────────────────┼─────────────────┼──────────────────┼────────────────┼──────────────────────┼────────────────┼─────────────────────────┼──────────────────┼─────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ C-2019-2020-Q4-2 │ P2000004       │ Breckenhill Inc.                                                                                                                 │ NULL               │ NULL       │ 2020-02-26    │ 0499                 │ Other professional services not elsewhere specified              │ Autres services professionnels non specifies ailleurs │ 2019-12-20            │ 2020-06-30    │ 39832.51       │ 24789.38       │ 15043.13        │ Increase contract by $15,043      │ Augmentation du contrat de 15 043 $         │ NULL                        │ NULL                                │ 0                   │ NULL            │ NULL        │ S              │ R019           │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ A3                    │ N                                 │ Y                     │ NULL               │ NULL                  │ A               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2019-2020-Q4     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada                                         │
# │ C-2019-2020-Q4-2 │ 2R008-19-0036  │ Adirondack Information Management, Inc., Amita Corporation, Artemp Personnel Services Inc., The AIM Group Inc., in Joint Venture │ NULL               │ NULL       │ 2019-05-08    │ 0473                 │ 0473 - Information Technology and Telecommunications Consultants │ 0473 - Consultants en TI et en télécommunications     │ 2019-05-08            │ 2021-03-31    │ 2546379.43     │ 1458850.16     │ 1087529.27      │ Contract with task authorizations │ Marché incluant des autorisations de tâches │ Resources for IM/IT Support │ Ressources pour le soutien en GI-TI │ Y                   │ NULL            │ NULL        │ S              │ D302A          │ CA                │ TC                     │ 00                       │ 00                         │ NULL                │ Y                                  │ B                     │ N                                 │ N                     │ PWSOSA             │ EN578-170432/311/EI   │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2019-2020-Q4     │ opc-cpvp    │ Office of the Privacy Commissioner of Canada | Commissariat à la protection de la vie privée du Canada │
# └──────────────────┴────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────┴────────────┴───────────────┴──────────────────────┴──────────────────────────────────────────────────────────────────┴───────────────────────────────────────────────────────┴───────────────────────┴───────────────┴────────────────┴────────────────┴─────────────────┴───────────────────────────────────┴─────────────────────────────────────────────┴─────────────────────────────┴─────────────────────────────────────┴─────────────────────┴─────────────────┴─────────────┴────────────────┴────────────────┴───────────────────┴────────────────────────┴──────────────────────────┴────────────────────────────┴─────────────────────┴────────────────────────────────────┴───────────────────────┴───────────────────────────────────┴───────────────────────┴────────────────────┴───────────────────────┴─────────────────┴──────────────────┴────────────────┴──────────────────────┴────────────────┴─────────────────────────┴──────────────────┴─────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
cleanContracts(con)

# %%
con.sql("""
SELECT
    COUNT(*) AS total_rows,
    COUNT(DISTINCT reference_number) AS unique_contracts
FROM contracts_clean;
""").pl().limit(20)
# Out:
# shape: (1, 2)
# ┌────────────┬──────────────────┐
# │ total_rows ┆ unique_contracts │
# │ ---        ┆ ---              │
# │ i64        ┆ i64              │
# ╞════════════╪══════════════════╡
# │ 1261327    ┆ 499635           │
# └────────────┴──────────────────┘

# %%
con.sql("""
SELECT * 
FROM contracts;
""")
# Out:
# ┌──────────────────────┬────────────────┬──────────────────────────────────────────────┬────────────────────┬────────────┬───────────────┬──────────────────────┬─────────────────────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────────┬───────────────────────┬───────────────┬────────────────┬────────────────┬─────────────────┬────────────────────────────────┬───────────────────────────────────────┬────────────────────────┬────────────────────────┬─────────────────────┬─────────────────┬─────────────┬────────────────┬────────────────┬───────────────────┬────────────────────────┬──────────────────────────┬────────────────────────────┬─────────────────────┬────────────────────────────────────┬───────────────────────┬───────────────────────────────────┬───────────────────────┬────────────────────┬───────────────────────┬─────────────────┬──────────────────┬────────────────┬──────────────────────┬────────────────┬─────────────────────────┬──────────────────┬─────────────┬──────────────────────────────────────────────────────────────────────────┐
# │   reference_number   │ procurement_id │                 vendor_name                  │ vendor_postal_code │ buyer_name │ contract_date │ economic_object_code │                               description_en                                │                                     description_fr                                      │ contract_period_start │ delivery_date │ contract_value │ original_value │ amendment_value │          comments_en           │              comments_fr              │ additional_comments_en │ additional_comments_fr │ agreement_type_code │ trade_agreement │ land_claims │ commodity_type │ commodity_code │ country_of_vendor │ solicitation_procedure │ limited_tendering_reason │ trade_agreement_exceptions │ indigenous_business │ indigenous_business_excluding_psib │ intellectual_property │ potential_commercial_exploitation │ former_public_servant │ contracting_entity │ standing_offer_number │ instrument_type │ ministers_office │ number_of_bids │ article_6_exceptions │ award_criteria │ socioeconomic_indicator │ reporting_period │  owner_org  │                             owner_org_title                              │
# │       varchar        │    varchar     │                   varchar                    │      varchar       │  varchar   │    varchar    │       varchar        │                                   varchar                                   │                                         varchar                                         │        varchar        │    varchar    │    varchar     │    varchar     │     varchar     │            varchar             │                varchar                │        varchar         │        varchar         │       varchar       │     varchar     │   varchar   │    varchar     │    varchar     │      varchar      │        varchar         │         varchar          │          varchar           │       varchar       │              varchar               │        varchar        │              varchar              │        varchar        │      varchar       │        varchar        │     varchar     │     varchar      │    varchar     │       varchar        │    varchar     │         varchar         │     varchar      │   varchar   │                                 varchar                                  │
# ├──────────────────────┼────────────────┼──────────────────────────────────────────────┼────────────────────┼────────────┼───────────────┼──────────────────────┼─────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────────┼───────────────────────┼───────────────┼────────────────┼────────────────┼─────────────────┼────────────────────────────────┼───────────────────────────────────────┼────────────────────────┼────────────────────────┼─────────────────────┼─────────────────┼─────────────┼────────────────┼────────────────┼───────────────────┼────────────────────────┼──────────────────────────┼────────────────────────────┼─────────────────────┼────────────────────────────────────┼───────────────────────┼───────────────────────────────────┼───────────────────────┼────────────────────┼───────────────────────┼─────────────────┼──────────────────┼────────────────┼──────────────────────┼────────────────┼─────────────────────────┼──────────────────┼─────────────┼──────────────────────────────────────────────────────────────────────────┤
# │ C-2019-2020-Q4-1     │ P2000002       │ Simzer Design Inc.                           │ NULL               │ NULL       │ 2020-02-26    │ 0351                 │ Communications professional services not elsewhere specified                │ Services professionnels de communications non specifies ailleurs                        │ 2019-11-15            │ 2020-05-30    │ 38900.25       │ 15255.0        │ 23645.25        │ Increase contract by $23,645   │ Augmentation du contrat de 23 645 $   │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ T005           │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ A3                    │ N                                 │ N                     │ NULL               │ NULL                  │ A               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2019-2020-Q4     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │ C-2019-2020-Q4-2     │ P2000004       │ Breckenhill Inc.                             │ NULL               │ NULL       │ 2020-02-26    │ 0499                 │ Other professional services not elsewhere specified                         │ Autres services professionnels non specifies ailleurs                                   │ 2019-12-20            │ 2020-06-30    │ 39832.51       │ 24789.38       │ 15043.13        │ Increase contract by $15,043   │ Augmentation du contrat de 15 043 $   │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ R019           │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ A3                    │ N                                 │ Y                     │ NULL               │ NULL                  │ A               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2019-2020-Q4     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │ C-2019-2020-Q4-3     │ P2000009       │ Spinal Cord Injury Canada                    │ NULL               │ NULL       │ 2020-03-11    │ 0494                 │ Translation services                                                        │ Services de traduction                                                                  │ 2020-03-16            │ 2020-07-31    │ 38420.0        │ 38420.0        │ 0.0             │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ R109           │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ A41                   │ Y                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2019-2020-Q4     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │ C-2019-2020-Q4-4     │ P2000011       │ CSA Group                                    │ NULL               │ NULL       │ 2020-03-11    │ 0491                 │ Management consulting                                                       │ Services de conseillers en gestion                                                      │ 2020-03-02            │ 2020-06-30    │ 39550.0        │ 39550.0        │ 0.0             │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ R019           │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ B                     │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2019-2020-Q4     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │ C-2019-2020-Q4-5     │ P2000014       │ Simzer Design Inc.                           │ NULL               │ NULL       │ 2020-03-20    │ 0351                 │ Communications professional services not elsewhere specified                │ Services professionnels de communications non specifies ailleurs                        │ 2020-03-02            │ 2020-08-31    │ 23571.8        │ 23571.8        │ 0.0             │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ T005           │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ A41                   │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2019-2020-Q4     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │ C-2020-2021-Q1-00001 │ P2000007       │ The Right Door Consulting & Solutions Inc.   │ NULL               │ NULL       │ 2020-05-04    │ 0499                 │ Other professional services not elsewhere specified                         │ Autres services professionnels non specifies ailleurs                                   │ 2020-01-23            │ 2020-12-31    │ 58752.94       │ 39168.63       │ 19584.31        │ Procurement services           │ Services d'achats                     │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ R019E          │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ A3                    │ N                                 │ N                     │ PWSOSA             │ E60ZT-1180027/184/ZT  │ SOSA            │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q1     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │ C-2020-2021-Q1-00002 │ P2000008       │ Sign Language Interpreting Associates Ottawa │ NULL               │ NULL       │ 2020-04-24    │ 0493                 │ Interpretation services                                                     │ Services d'interpretation                                                               │ 2020-04-01            │ 2021-03-31    │ 40000.0        │ 40000.0        │ NULL            │ Intepretation services for web │ Services d'interpretation pour le web │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ R109D          │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ A41                   │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q1     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │ C-2020-2021-Q1-00003 │ P2100001       │ OpenConcept Consulting Inc.                  │ NULL               │ NULL       │ 2020-06-26    │ 0473                 │ Information Technology and Telecommunications Consultants                   │ Experts-conseils en technologie de l'information                                        │ 2020-06-26            │ 2020-11-30    │ 40000.0        │ 40000.0        │ NULL            │ Website migration              │ Migration du site web                 │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ D302A          │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ B                     │ N                                 │ N                     │ PWSOSA             │ E60ZT-1180026/027/ZT  │ SOSA            │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q1     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │ C-2020-2021-Q2-00001 │ P2100005       │ Boardroom Metrics, Inc                       │ NULL               │ NULL       │ 2020-09-24    │ 0499                 │ Other professional services not elsewhere specified                         │ Autres services professionnels non specifies ailleurs                                   │ 2020-09-22            │ 2020-01-31    │ 27120.0        │ 27120.0        │ NULL            │ Board assessment               │ Evaluation du CA                      │ NULL                   │ NULL                   │ NULL                │ XX              │ NA          │ S              │ RO19E          │ CA                │ TN                     │ 00                       │ 00                         │ NA                  │ N                                  │ B                     │ N                                 │ N                     │ DC                 │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q2     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │ C-2020-2021-Q3-00001 │ P2100001       │ OpenConcept Consulting Inc.                  │ K1R                │ NULL       │ 2020-06-26    │ 473                  │ 0473 Information Technology and Telecommunications Consultants              │ 0473 Information Technology and Telecommunications Consultants                          │ 2020-06-26            │ 2021-02-28    │ 60000          │ 40000          │ 20000           │ Website migration              │ Migration du site web                 │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ D302A          │ CA                │ TN                     │ 85                       │ 00                         │ NA                  │ N                                  │ B                     │ N                                 │ N                     │ PWSOSA             │ E60ZT-180026/027/ZT   │ A               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ casdo-ocena │ Accessibility Standards Canada | Normes d’accessibilité Canada           │
# │          ·           │    ·           │            ·                                 │  ·                 │  ·         │     ·         │  ·                   │                               ·                                             │                               ·                                                         │     ·                 │     ·         │   ·            │   ·            │ ·               │  ·                             │  ·                                    │  ·                     │  ·                     │ ·                   │  ·              │  ·          │ ·              │  ·             │ ·                 │ ·                      │ ·                        │ ·                          │ ·                   │ ·                                  │ ·                     │ ·                                 │ ·                     │  ·                 │  ·                    │ ·               │ ·                │  ·             │  ·                   │  ·             │  ·                      │      ·           │    ·        │                               ·                                          │
# │          ·           │    ·           │            ·                                 │  ·                 │  ·         │     ·         │  ·                   │                               ·                                             │                               ·                                                         │     ·                 │     ·         │   ·            │   ·            │ ·               │  ·                             │  ·                                    │  ·                     │  ·                     │ ·                   │  ·              │  ·          │ ·              │  ·             │ ·                 │ ·                      │ ·                        │ ·                          │ ·                   │ ·                                  │ ·                     │ ·                                 │ ·                     │  ·                 │  ·                    │ ·               │ ·                │  ·             │  ·                   │  ·             │  ·                      │      ·           │    ·        │                               ·                                          │
# │          ·           │    ·           │            ·                                 │  ·                 │  ·         │     ·         │  ·                   │                               ·                                             │                               ·                                                         │     ·                 │     ·         │   ·            │   ·            │ ·               │  ·                             │  ·                                    │  ·                     │  ·                     │ ·                   │  ·              │  ·          │ ·              │  ·             │ ·                 │ ·                      │ ·                        │ ·                          │ ·                   │ ·                                  │ ·                     │ ·                                 │ ·                     │  ·                 │  ·                    │ ·               │ ·                │  ·             │  ·                   │  ·             │  ·                      │      ·           │    ·        │                               ·                                          │
# │ C-2020-2021-Q3-00366 │ 3000717710     │ NANOSTRING TECHNOLOGIES                      │ NULL               │ NULL       │ 2020-12-07    │ 1243                 │ Measuring, controlling, laboratory, medical and optical equipment and parts │ Instruments de mesure, de contrôle, de laboratoire-Instruments de médecine et d'optique │ 2020-12-07            │ 2020-12-31    │ 10910.75       │ 10910.75       │ 0               │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ G              │ 6600           │ US                │ TN                     │ 71                       │ 00                         │ NULL                │ N                                  │ C                     │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# │ C-2020-2021-Q3-00367 │ 3000717751     │ BIO S & T INC                                │ NULL               │ NULL       │ 2020-12-08    │ 430                  │ Scientific services                                                         │ Services scientifiques                                                                  │ 2020-12-08            │ 2021-03-31    │ 12538.45       │ 12538.45       │ 0               │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ H300           │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ A5                    │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# │ C-2020-2021-Q3-00368 │ 3000717795     │ LABORATORY SERVICES                          │ NULL               │ NULL       │ 2020-12-08    │ 430                  │ Scientific services                                                         │ Services scientifiques                                                                  │ 2020-12-08            │ 2021-03-31    │ 12339.6        │ 12339.6        │ 0               │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ H300           │ CA                │ TN                     │ 05                       │ 00                         │ NULL                │ N                                  │ A5                    │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# │ C-2020-2021-Q3-00369 │ 3000717810     │ HOSKIN SCIENTIFIC LTD                        │ NULL               │ NULL       │ 2020-12-09    │ 1243                 │ Measuring, controlling, laboratory, medical and optical equipment and parts │ Instruments de mesure, de contrôle, de laboratoire-Instruments de médecine et d'optique │ 2020-12-09            │ 2021-03-31    │ 24706.6        │ 24706.6        │ 0               │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ G              │ 6685           │ CA                │ TC                     │ 00                       │ 00                         │ NULL                │ N                                  │ C                     │ N                                 │ N                     │ PWSOSA             │ E60PV-19EQUI/008/PV   │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# │ C-2020-2021-Q3-00370 │ 3000717819     │ ILLUMINA CANADA ULC                          │ NULL               │ NULL       │ 2020-12-09    │ 1139                 │ Miscellaneous Chemical products                                             │ Produits chimiques divers                                                               │ 2020-12-09            │ 2020-12-31    │ 23445.24       │ 23445.24       │ 0               │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ G              │ 6810           │ CA                │ TC                     │ 00                       │ 00                         │ NULL                │ N                                  │ C                     │ N                                 │ N                     │ PWSOSA             │ E60PV-17CS00/004/PV   │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# │ C-2020-2021-Q3-00371 │ 3000717849     │ LEICA MICROSYSTEMS (CANADA) INC.             │ NULL               │ NULL       │ 2020-12-09    │ 1243                 │ Measuring, controlling, laboratory, medical and optical equipment and parts │ Instruments de mesure, de contrôle, de laboratoire-Instruments de médecine et d'optique │ 2020-12-09            │ 2021-01-09    │ 10219.66       │ 10219.66       │ 0               │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ G              │ 6600           │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ C                     │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# │ C-2020-2021-Q3-00372 │ 3000717859     │ VWR INTERNATIONAL CO                         │ NULL               │ NULL       │ 2020-12-09    │ 1243                 │ Measuring, controlling, laboratory, medical and optical equipment and parts │ Instruments de mesure, de contrôle, de laboratoire-Instruments de médecine et d'optique │ 2020-12-09            │ 2021-03-31    │ 24826.1        │ 24826.1        │ 0               │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ G              │ 6600           │ CA                │ TC                     │ 00                       │ 00                         │ NULL                │ N                                  │ C                     │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# │ C-2020-2021-Q3-00373 │ 3000717874     │ FROSTBITE MECHANICAL                         │ NULL               │ NULL       │ 2020-12-09    │ 619                  │ Electric power installations                                                │ Réseaux électriques                                                                     │ 2020-12-09            │ 2021-03-26    │ 38272.5        │ 38272.5        │ 0               │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ C              │ 5164           │ CA                │ TC                     │ 00                       │ 00                         │ NULL                │ N                                  │ C                     │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# │ C-2020-2021-Q3-00374 │ 20210303A      │ THERMO FISHER SCIENTIFIC                     │ NULL               │ NULL       │ 2020-12-09    │ 1243                 │ Measuring, controlling, laboratory, medical and optical equipment and parts │ Instruments de mesure, de contrôle, de laboratoire-Instruments de médecine et d'optique │ 2020-12-09            │ 2021-03-31    │ 62521.02       │ 62521.02       │ 0               │ NULL                           │ NULL                                  │ NULL                   │ NULL                   │ I                   │ NULL            │ NULL        │ G              │ 6600           │ CA                │ OB                     │ 00                       │ 00                         │ NULL                │ N                                  │ C                     │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# │ C-2020-2021-Q3-00375 │ 3000717648     │ UNIVERSITY OF ALBERTA                        │ NULL               │ NULL       │ 2020-12-10    │ 491                  │ Management consulting                                                       │ Services de conseillers en gestion                                                      │ 2020-12-10            │ 2021-03-20    │ 20000          │ 20000          │ 0               │ Data Collection Services       │ Services de collecte de données       │ NULL                   │ NULL                   │ 0                   │ NULL            │ NULL        │ S              │ R113           │ CA                │ TN                     │ 85                       │ 00                         │ NULL                │ N                                  │ A5                    │ N                                 │ N                     │ NULL               │ NULL                  │ C               │ N                │ NULL           │ NULL                 │ NULL           │ NULL                    │ 2020-2021-Q3     │ aafc-aac    │ Agriculture and Agri-Food Canada | Agriculture et Agroalimentaire Canada │
# ├──────────────────────┴────────────────┴──────────────────────────────────────────────┴────────────────────┴────────────┴───────────────┴──────────────────────┴─────────────────────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────────┴───────────────────────┴───────────────┴────────────────┴────────────────┴─────────────────┴────────────────────────────────┴───────────────────────────────────────┴────────────────────────┴────────────────────────┴─────────────────────┴─────────────────┴─────────────┴────────────────┴────────────────┴───────────────────┴────────────────────────┴──────────────────────────┴────────────────────────────┴─────────────────────┴────────────────────────────────────┴───────────────────────┴───────────────────────────────────┴───────────────────────┴────────────────────┴───────────────────────┴─────────────────┴──────────────────┴────────────────┴──────────────────────┴────────────────┴─────────────────────────┴──────────────────┴─────────────┴──────────────────────────────────────────────────────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  43 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
